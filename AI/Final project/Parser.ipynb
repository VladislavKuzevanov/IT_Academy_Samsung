# %%
import requests
import json
import re
import os

# %%
def get_reviews_on_page(endCursor, movieId):
    r = requests.get(f"https://www.rottentomatoes.com/napi/movie/{movieId}/reviews/user",
    params = {
        "direction": "next",
        "endCursor": endCursor,
        "startCursor": ""
    })
    return r.json()

# %%
def get_reviews(url: str):
    reviews = []
    url=url
    filmname = url.split('/')[4]
    print(filmname)
    result = requests.get(url)
    data = json.loads(re.search('movieReview\s=\s(.*);', result.text).group(1))
    movieId = data["movieId"]
    # os.mkdir(f'Data/{filmname}')
    for i in range(0, 10):
        try:
            result = get_reviews_on_page(result["pageInfo"]["endCursor"] if i != 0  else "", movieId)
            count = 0
            for t in result["reviews"]:
                count += 1
                reviews.append(t["review"])
                # with open(f'Data/{filmname}/{filmname}_{i+1}_{count}.txt', 'w') as f:
                    # f.write(t['review'])
            print(f"reviews from page [{i+1}] have been added")
        except:
            print('No more pages with reviews')
            break
    return reviews

# %%
url = 'https://www.rottentomatoes.com/m/godzilla_vs_kong/reviews?type=user'
get_reviews(url)[5]
# Out:
# godzilla_vs_kong
# reviews from page [1] have been added
# reviews from page [2] have been added
# reviews from page [3] have been added
# reviews from page [4] have been added
# reviews from page [5] have been added
# reviews from page [6] have been added
# reviews from page [7] have been added
# reviews from page [8] have been added
# reviews from page [9] have been added
# reviews from page [10] have been added
# "Godzilla VS KONG was absolutely one of the best movies I have ever seen in 2021 and in my life. #TeamGodzilla all the way but I love how they made kong so human and had that special bond with Jia. The fight scenes were epic( especially the one in the middle of the ocean). The final fight scene was amazing where they fought together against MechaGodzilla were Godzilla powered kong's axe which could deal devastating blows to the living weapon. I highly recommend this movie be watched in theatres( If you can). Your gonna have so much fun and intensity while watching this movie. Not to mention more monsters will be appearing including the return of a Skullcrawler and one of Ghidorah's Skull's. Ending was awesome when both of them showed mutual respect for each and Godzilla roared(which was just marvelous)"

# %%
url = 'https://www.rottentomatoes.com/m/godzilla_vs_kong/reviews?type=user'
result = requests.get(url)
data = json.loads(re.search('movieReview\s=\s(.*);', result.text).group(1))
movieId = data["movieId"]
result = get_reviews_on_page(result["pageInfo"]["endCursor"] if 0 != 0  else "", movieId)

# %%
result["reviews"][0]['review']
# Out:
# "Giant hairy man vs larger pet lizard after he ate the man's last pizza slice."
